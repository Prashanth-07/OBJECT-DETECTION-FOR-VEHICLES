# %%
# !nvidia-smi
# Out:
# /bin/bash: line 1: nvidia-smi: command not found

# %%
# !pip install ultralytics
# Out:
# Collecting ultralytics
#   Downloading ultralytics-8.1.11-py3-none-any.whl (709 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 709.5/709.5 kB 4.2 MB/s eta 0:00:00
# Requirement already satisfied: matplotlib>=3.3.0 in /usr/local/lib/python3.10/dist-packages (from ultralytics) (3.7.1)
# Requirement already satisfied: numpy>=1.22.2 in /usr/local/lib/python3.10/dist-packages (from ultralytics) (1.23.5)
# Requirement already satisfied: opencv-python>=4.6.0 in /usr/local/lib/python3.10/dist-packages (from ultralytics) (4.8.0.76)
# Requirement already satisfied: pillow>=7.1.2 in /usr/local/lib/python3.10/dist-packages (from ultralytics) (9.4.0)
# Requirement already satisfied: pyyaml>=5.3.1 in /usr/local/lib/python3.10/dist-packages (from ultralytics) (6.0.1)
# Requirement already satisfied: requests>=2.23.0 in /usr/local/lib/python3.10/dist-packages (from ultralytics) (2.31.0)
# Requirement already satisfied: scipy>=1.4.1 in /usr/local/lib/python3.10/dist-packages (from ultralytics) (1.11.4)
# Requirement already satisfied: torch>=1.8.0 in /usr/local/lib/python3.10/dist-packages (from ultralytics) (2.1.0+cu121)
# Requirement already satisfied: torchvision>=0.9.0 in /usr/local/lib/python3.10/dist-packages (from ultralytics) (0.16.0+cu121)
# Requirement already satisfied: tqdm>=4.64.0 in /usr/local/lib/python3.10/dist-packages (from ultralytics) (4.66.1)
# Requirement already satisfied: psutil in /usr/local/lib/python3.10/dist-packages (from ultralytics) (5.9.5)
# Requirement already satisfied: py-cpuinfo in /usr/local/lib/python3.10/dist-packages (from ultralytics) (9.0.0)
# Collecting thop>=0.1.1 (from ultralytics)
#   Downloading thop-0.1.1.post2209072238-py3-none-any.whl (15 kB)
# Requirement already satisfied: pandas>=1.1.4 in /usr/local/lib/python3.10/dist-packages (from ultralytics) (1.5.3)
# Requirement already satisfied: seaborn>=0.11.0 in /usr/local/lib/python3.10/dist-packages (from ultralytics) (0.13.1)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.3.0->ultralytics) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.3.0->ultralytics) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.3.0->ultralytics) (4.48.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.3.0->ultralytics) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.3.0->ultralytics) (23.2)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.3.0->ultralytics) (3.1.1)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.3.0->ultralytics) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.1.4->ultralytics) (2023.4)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.23.0->ultralytics) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.23.0->ultralytics) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.23.0->ultralytics) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.23.0->ultralytics) (2024.2.2)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.0->ultralytics) (3.13.1)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.0->ultralytics) (4.9.0)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.0->ultralytics) (1.12)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.0->ultralytics) (3.2.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.0->ultralytics) (3.1.3)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.0->ultralytics) (2023.6.0)
# Requirement already satisfied: triton==2.1.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.0->ultralytics) (2.1.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib>=3.3.0->ultralytics) (1.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=1.8.0->ultralytics) (2.1.5)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch>=1.8.0->ultralytics) (1.3.0)
# Installing collected packages: thop, ultralytics
# Successfully installed thop-0.1.1.post2209072238 ultralytics-8.1.11

# %%
# !yolo predict model=yolov8n.pt source='https://ultralytics.com/images/bus.jpg'
# Out:
# Downloading https://github.com/ultralytics/assets/releases/download/v8.1.0/yolov8n.pt to 'yolov8n.pt'...
# 100% 6.23M/6.23M [00:00<00:00, 88.1MB/s]
# Ultralytics YOLOv8.1.10 🚀 Python-3.10.12 torch-2.1.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# YOLOv8n summary (fused): 168 layers, 3151904 parameters, 0 gradients, 8.7 GFLOPs
#
# Downloading https://ultralytics.com/images/bus.jpg to 'bus.jpg'...
# 100% 476k/476k [00:00<00:00, 13.8MB/s]
# image 1/1 /content/bus.jpg: 640x480 4 persons, 1 bus, 1 stop sign, 83.2ms
# Speed: 13.6ms preprocess, 83.2ms inference, 760.8ms postprocess per image at shape (1, 3, 640, 480)
# Results saved to runs/detect/predict
# 💡 Learn more at https://docs.ultralytics.com/modes/predict

# %%
# !pip install ultralytics
# !pip install ipython
from IPython.display import clear_output
clear_output()

import ultralytics
ultralytics.checks()
# Out:
# Ultralytics YOLOv8.1.11 🚀 Python-3.10.12 torch-2.1.0+cu121 CPU (Intel Xeon 2.20GHz)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 26.3/107.7 GB disk)

# %%
from ultralytics import YOLO

from IPython.display import display, Image

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd /content/drive/MyDrive/Yolov8
# Out:
# /content/drive/MyDrive/Yolov8

# %%
# !ls
# Out:
# data  data.yaml  runs  yolov8.ipynb  yolov8n.pt

# %%
# %cd /content/drive/MyDrive/Yolov8

model = YOLO("yolov8n.yaml")  # build a new model from scratch
model = YOLO("yolov8n.pt")  # load a pretrained model (recommended for training)

# Use the model
model.train(data="data.yaml", epochs=10)
metrics = model.val()
# Out:
# /content/drive/MyDrive/Yolov8
# Ultralytics YOLOv8.1.11 🚀 Python-3.10.12 torch-2.1.0+cu121 CPU (Intel Xeon 2.20GHz)
# engine/trainer: task=detect, mode=train, model=yolov8n.pt, data=data.yaml, epochs=10, time=None, patience=50, batch=16, imgsz=640, save=True, save_period=-1, cache=False, device=None, workers=8, project=None, name=train2, exist_ok=False, pretrained=True, optimizer=auto, verbose=True, seed=0, deterministic=True, single_cls=False, rect=False, cos_lr=False, close_mosaic=10, resume=False, amp=True, fraction=1.0, profile=False, freeze=None, multi_scale=False, overlap_mask=True, mask_ratio=4, dropout=0.0, val=True, split=val, save_json=False, save_hybrid=False, conf=None, iou=0.7, max_det=300, half=False, dnn=False, plots=True, source=None, vid_stride=1, stream_buffer=False, visualize=False, augment=False, agnostic_nms=False, classes=None, retina_masks=False, embed=None, show=False, save_frames=False, save_txt=False, save_conf=False, save_crop=False, show_labels=True, show_conf=True, show_boxes=True, line_width=None, format=torchscript, keras=False, optimize=False, int8=False, dynamic=False, simplify=False, opset=None, workspace=4, nms=False, lr0=0.01, lrf=0.01, momentum=0.937, weight_decay=0.0005, warmup_epochs=3.0, warmup_momentum=0.8, warmup_bias_lr=0.1, box=7.5, cls=0.5, dfl=1.5, pose=12.0, kobj=1.0, label_smoothing=0.0, nbs=64, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, degrees=0.0, translate=0.1, scale=0.5, shear=0.0, perspective=0.0, flipud=0.0, fliplr=0.5, mosaic=1.0, mixup=0.0, copy_paste=0.0, auto_augment=randaugment, erasing=0.4, crop_fraction=1.0, cfg=None, tracker=botsort.yaml, save_dir=runs/detect/train2
# Downloading https://ultralytics.com/assets/Arial.ttf to '/root/.config/Ultralytics/Arial.ttf'...
# 100%|██████████| 755k/755k [00:00<00:00, 12.6MB/s]
# Overriding model.yaml nc=80 with nc=32
#
#                    from  n    params  module                                       arguments
#   0                  -1  1       464  ultralytics.nn.modules.conv.Conv             [3, 16, 3, 2]
#   1                  -1  1      4672  ultralytics.nn.modules.conv.Conv             [16, 32, 3, 2]
#   2                  -1  1      7360  ultralytics.nn.modules.block.C2f             [32, 32, 1, True]
#   3                  -1  1     18560  ultralytics.nn.modules.conv.Conv             [32, 64, 3, 2]
#   4                  -1  2     49664  ultralytics.nn.modules.block.C2f             [64, 64, 2, True]
#   5                  -1  1     73984  ultralytics.nn.modules.conv.Conv             [64, 128, 3, 2]
#   6                  -1  2    197632  ultralytics.nn.modules.block.C2f             [128, 128, 2, True]
#   7                  -1  1    295424  ultralytics.nn.modules.conv.Conv             [128, 256, 3, 2]
#   8                  -1  1    460288  ultralytics.nn.modules.block.C2f             [256, 256, 1, True]
#   9                  -1  1    164608  ultralytics.nn.modules.block.SPPF            [256, 256, 5]
#  10                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  11             [-1, 6]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  12                  -1  1    148224  ultralytics.nn.modules.block.C2f             [384, 128, 1]
#  13                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  14             [-1, 4]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  15                  -1  1     37248  ultralytics.nn.modules.block.C2f             [192, 64, 1]
#  16                  -1  1     36992  ultralytics.nn.modules.conv.Conv             [64, 64, 3, 2]
#  17            [-1, 12]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  18                  -1  1    123648  ultralytics.nn.modules.block.C2f             [192, 128, 1]
#  19                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#  20             [-1, 9]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  21                  -1  1    493056  ultralytics.nn.modules.block.C2f             [384, 256, 1]
#  22        [15, 18, 21]  1    757552  ultralytics.nn.modules.head.Detect           [32, [64, 128, 256]]
# Model summary: 225 layers, 3017088 parameters, 3017072 gradients, 8.2 GFLOPs
#
# Transferred 319/355 items from pretrained weights
# TensorBoard: Start with 'tensorboard --logdir runs/detect/train2', view at http://localhost:6006/
# Freezing layer 'model.22.dfl.conv.weight'
# train: Scanning /content/drive/MyDrive/Yolov8/data/train/labels.cache... 8491 images, 10 backgrounds, 1399 corrupt: 100%|██████████| 8501/8501 [00:00<?, ?it/s]
# train: WARNING ⚠️ /content/drive/MyDrive/Yolov8/data/train/images/-9bd1fb0493d1c729_JPG.rf.739f3258436ce024015a0d1765e24c4c.jpg: ignoring corrupt image/label: Label class 100 exceeds dataset class count 32. Possible class labels are 0-31
# train: WARNING ⚠️ /content/drive/MyDrive/Yolov8/data/train/images/005980b3a5f93085_jpg.rf.2QZCXGReqcBORWQJKQfO.jpg: ignoring corrupt image/label: Label class 300 exceeds dataset class count 32. Possible class labels are 0-31
# train: WARNING ⚠️ /content/drive/MyDrive/Yolov8/data/train/images/005980b3a5f93085_jpg.rf.68f1ed44dbca53b707a1d3d82d4b7d9a.jpg: ignoring corrupt image/label: Label class 300 exceeds dataset class count 32. Possible class labels are 0-31
# train: WARNING ⚠️ /content/drive/MyDrive/Yolov8/data/train/images/00aaf0a0a9ee7e71_jpg.rf.808b1e59067887493dffad63561c2a9d.jpg: ignoring corrupt image/label: Label class 300 exceeds dataset class count 32. Possible class labels are 0-31
# train: WARNING ⚠️ /content/drive/MyDrive/Yolov8/data/train/images/00aaf0a0a9ee7e71_jpg.rf.KBCzX2HtZviBuQY9JDTQ.jpg: ignoring corrupt image/label: Label class 300 exceeds dataset class count 32. Possible class labels are 0-31
# train: WARNING ⚠️ /content/drive/MyDrive/Yolov8/data/train/images/00e0422e47cdbeb7_jpg.rf.a8b6f2ef17a14eb8b9228d26366a124d.jpg: ignoring corrupt image/label: Label class 300 exceeds dataset class count 32. Possible class labels are 0-31
# train: WARNING ⚠️ /content/drive/MyDrive/Yolov8/data/train/images/00e0422e47cdbeb7_jpg.rf.yHmAn1jB2oy8XzzQPBzc.jpg: ignoring corrupt image/label: Label class 300 exceeds dataset class count 32. Possible class labels are 0-31
# train: WARNING ⚠️ /content/drive/MyDrive/Yolov8/data/train/images/00e13aca7d2f904a_jpg.rf.52342966f5a37167f8cfd7ea3f4dacef.jpg: ignoring corrupt image/label: Label class 300 exceeds dataset class count 32. Possible class labels are 0-31
# train: WARNING ⚠️ /content/drive/MyDrive/Yolov8/data/train/images/00e13aca7d2f904a_jpg.rf.eQwpgo07vRFeI7SgvXy6.jpg: ignoring corrupt image/label: Label class 300 exceeds dataset class count 32. Possible class labels are 0-31
# train: WARNING ⚠️ /content/drive/MyDrive/Yolov8/data/train/images/00e2d9121adc0c20_jpg.rf.50fa25618ccc9f0ebf59f2ffe64cf298.jpg: ignoring corrupt image/label: Label class 300 exceeds dataset class count 32. Possible class labels are 0-31
# train: WARNING ⚠️ /content/drive/MyDrive/Yolov8/data/train/images/00e2d9121adc0c20_jpg.rf.rPP5CqB9mOv9wnRTTKR3.jpg: ignoring corrupt image/label: Label class 300 exceeds dataset class count 32. Possible class labels are 0-31
# train: WARNING ⚠️ /content/drive/MyDrive/Yolov8/data/train/images/011a8a0a921c2376_jpg.rf.064272f1b667f68b4340d240244ff7e8.jpg: ignoring corrupt image/label: Label class 300 exceeds dataset class count 32. Possible class labels are 0-31
# train: WARNING ⚠️ /content/drive/MyDrive/Yolov8/data/train/images/011a8a0a921c2376_jpg.rf.tflPpvQDTaDj9gH1xuDJ.jpg: ignoring corrupt image/label: Label class 300 exceeds dataset class count 32. Possible class labels are 0-31
# train: WARNING ⚠️ /content/drive/MyDrive/Yolov8/data/train/images/0133391d627e6df4_jpg.rf.5fb6cc71948fdee8e2e7cbc9bbc5aeb1.jpg: ignoring corrupt image/label: Label class 300 exceeds dataset class count 32. Possible class labels are 0-31
# train: WARNING ⚠️ /content/drive/MyDrive/Yolov8/data/train/images/0133391d627e6df4_jpg.rf.xszyOWdyIGCiI2HmiGNr.jpg: ignoring corrupt image/label: Label class 300 exceeds dataset class count 32. Possible class labels are 0-31
# train: WARNING ⚠️ /content/drive/MyDrive/Yolov8/data/train/images/013476982d77e380_jpg.rf.3abcf2c4c484148e9e88d3c8c99bc236.jpg: ignoring corrupt image/label: Label class 300 exceeds dataset class count 32. Possible class labels are 0-31
# train: WARNING ⚠️ /content/drive/MyDrive/Yolov8/data/train/images/013476982d77e380_jpg.rf.E6oudaF78aSJULyWaSIS.jpg: ignoring corrupt image/label: Label class 300 exceeds dataset class count 32. Possible class labels are 0-31
# train: WARNING ⚠️ /content/drive/MyDrive/Yolov8/data/train/images/0158307c4ad94b38_jpg.rf.6VgRLvEWkhSwfdBdY9Fi.jpg: ignoring corrupt image/label: Label class 300 exceeds dataset class count 32. Possible class labels are 0-31
# train: WARNING ⚠️ /content/drive/MyDrive/Yolov8/data/train/images/0158307c4ad94b38_jpg.rf.7c3ac0278eaf3a1773359994c4679aca.jpg: ignoring corrupt image/label: Label class 300 exceeds dataset class count 32. Possible class labels are 0-31
# train: WARNING ⚠️ /content/drive/MyDrive/Yolov8/data/train/images/020fcce8dd0c0653_jpg.rf.5d56c4b986d3e468e6513d79a34dc211.jpg: ignoring corrupt image/label: Label class 300 exceeds dataset class count 32. Possible class labels are 0-31
# train: WARNING ⚠️ /content/drive/MyDrive/Yolov8/data/train/images/020fcce8dd0c0653_jpg.rf.YHXo4M57w09raw4bkB19.jpg: ignoring corrupt image/label: Label class 300 exceeds dataset class count 32. Possible class labels are 0-31
# train: WARNING ⚠️ /content/drive/MyDrive/Yolov8/data/train/images/02178f3aa9e8b0d1_jpg.rf.704fc24e41f5f2a604fab8a066f84f8c.jpg: ignoring corrupt image/label: Label class 300 exceeds dataset class count 32. Possible class labels are 0-31
# train: WARNING ⚠️ /content/drive/MyDrive/Yolov8/data/train/images/02178f3aa9e8b0d1_jpg.rf.ylUGMmNfzKUMq3VOVyGD.jpg: ignoring corrupt image/label: Label class 300 exceeds dataset class count 32. Possible class labels are 0-31
# train: WARNING ⚠️ /content/drive/MyDrive/Yolov8/data/train/images/024a282cdc754de8_jpg.rf.44u6VPjwAgn89uVtquBu.jpg: ignoring corrupt image/label: Label class 300 exceeds dataset class count 32. Possible class labels are 0-31
# train: WARNING ⚠️ /content/drive/MyDrive/Yolov8/data/train/images/024a282cdc754de8_jpg.rf.b4951b9370248704b3b1d1c750cc4fba.jpg: ignoring corrupt image/label: Label class 300 exceeds dataset class count 32. Possible class labels are 0-31
# train: WARNING ⚠️ /content/drive/MyDrive/Yolov8/data/train/images/02d437a356a7c16e_jpg.rf.a0d37064c126f5e2bf3493b06bb94b4a.jpg: ignoring corrupt image/label: Label class 300 exceeds dataset class count 32. Possible class labels are 0-31
# train: WARNING ⚠️ /content/drive/MyDrive/Yolov8/data/train/images/02d437a356a7c16e_jpg.rf.vHLFLzl61byax6BaLMCP.jpg: ignoring corrupt image/label: Label class 300 exceeds dataset class count 32. Possible class labels are 0-31
# train: WARNING ⚠️ /content/drive/MyDrive/Yolov8/data/train/images/031a836081712b50_jpg.rf.f82a0c39ba3dfac17be325452c7b2b06.jpg: ignoring corrupt image/label: Label class 300 exceeds dataset class count 32. Possible class labels are 0-31
# train: WARNING ⚠️ /content/drive/MyDrive/Yolov8/data/train/images/031a836081712b50_jpg.rf.wZjpl3ylNPHAO9WnRAWH.jpg: ignoring corrupt image/label: Label class 300 exceeds dataset class count 32. Possible class labels are 0-31
# train: WARNING ⚠️ /content/drive/MyDrive/Yolov8/data/train/images/040d25a99e7b675b_jpg.rf.UIHiGJcPfPY36egSAJft.jpg: ignoring corrupt image/label: Label class 300 exceeds dataset class count 32. Possible class labels are 0-31
# train: WARNING ⚠️ /content/drive/MyDrive/Yolov8/data/train/images/040d25a99e7b675b_jpg.rf.e1b3ced8dbbc7905d4fe5ac30622a419.jpg: ignoring corrupt image/label: Label class 300 exceeds dataset class count 32. Possible class labels are 0-31
# train: WARNING ⚠️ /content/drive/MyDrive/Yolov8/data/train/images/041e674d0d9a45ec_jpg.rf.57186db30275039dfd2ce804b9626963.jpg: ignoring corrupt image/label: Label class 300 exceeds dataset class count 32. Possible class labels are 0-31
# train: WARNING ⚠️ /content/drive/MyDrive/Yolov8/data/train/images/041e674d0d9a45ec_jpg.rf.LMTUDjIPeUHgU4b68RVZ.jpg: ignoring corrupt image/label: Label class 300 exceeds dataset class count 32. Possible class labels are 0-31
# train: WARNING ⚠️ /content/drive/MyDrive/Yolov8/data/train/images/045f8f2e4c2e3077_jpg.rf.107779352cd8cac31411952fc53cf99d.jpg: ignoring corrupt image/label: Label class 300 exceeds dataset class count 32. Possible class labels are 0-31
# train: WARNING ⚠️ /content/drive/MyDrive/Yolov8/data/train/images/045f8f2e4c2e3077_jpg.rf.UTYIHRlCuTNPmBhGUQ8A.jpg: ignoring corrupt image/label: Label class 300 exceeds dataset class count 32. Possible class labels are 0-31
# train: WARNING ⚠️ /content/drive/MyDrive/Yolov8/data/train/images/04c1d6c2570a7c42_jpg.rf.332b41cd0fd290fd0506dac060c1b7d6.jpg: ignoring corrupt image/label: Label class 300 exceeds dataset class count 32. Possible class labels are 0-31
# train: WARNING ⚠️ /content/drive/MyDrive/Yolov8/data/train/images/04c1d6c2570a7c42_jpg.rf.lr5lXwTFgr3zrVckI5ln.jpg: ignoring corrupt image/label: Label class 300 exceeds dataset class count 32. Possible class labels are 0-31
# train: WARNING ⚠️ /content/drive/MyDrive/Yolov8/data/train/images/062e230c4506d21d_jpg.rf.49faa5bf56e061d53eaa7bdf92a86e1f.jpg: ignoring corrupt image/label: Label class 300 exceeds dataset class count 32. Possible class labels are 0-31
# train: WARNING ⚠️ /content/drive/MyDrive/Yolov8/data/train/images/062e230c4506d21d_jpg.rf.q5Myo3uQH66PI6XvzCpd.jpg: ignoring corrupt image/label: Label class 300 exceeds dataset class count 32. Possible class labels are 0-31
# train: WARNING ⚠️ /content/drive/MyDrive/Yolov8/data/train/images/067e7d6c015a431d_jpg.rf.76bce3c01ba4c9d60c0e94b3c01bdca4.jpg: ignoring corrupt image/label: Label class 300 exceeds dataset class count 32. Possible class labels are 0-31
# train: WARNING ⚠️ /content/drive/MyDrive/Yolov8/data/train/images/067e7d6c015a431d_jpg.rf.Sc4J72rjXVYLyfPXCLhr.jpg: ignoring corrupt image/label: Label class 300 exceeds dataset class count 32. Possible class labels are 0-31
# train: WARNING ⚠️ /content/drive/MyDrive/Yolov8/data/train/images/068868f40fb6dbec_jpg.rf.TuNx4cAV28rilGbgRwVh.jpg: ignoring corrupt image/label: Label class 300 exceeds dataset class count 32. Possible class labels are 0-31
# train: WARNING ⚠️ /content/drive/MyDrive/Yolov8/data/train/images/068868f40fb6dbec_jpg.rf.bd6b74811d9dd31a359a15d69dcb3d60.jpg: ignoring corrupt image/label: Label class 300 exceeds dataset class count 32. Possible class labels are 0-31
# train: WARNING ⚠️ /content/drive/MyDrive/Yolov8/data/train/images/076317ab4c925aa9_jpg.rf.2eab8692c9e3035eb3c2dfcd2a07e74c.jpg: ignoring corrupt image/label: Label class 300 exceeds dataset class count 32. Possible class labels are 0-31
# train: WARNING ⚠️ /content/drive/MyDrive/Yolov8/data/train/images/076317ab4c925aa9_jpg.rf.x5RZRLSFK0S4b63wchyT.jpg: ignoring corrupt image/label: Label class 300 exceeds dataset class count 32. Possible class labels are 0-31
# train: WARNING ⚠️ /content/drive/MyDrive/Yolov8/data/train/images/0777838554ecb1eb_jpg.rf.9e11b73a1dae5675124c22e13f73f1f5.jpg: ignoring corrupt image/label: Label class 300 exceeds dataset class count 32. Possible class labels are 0-31
# train: WARNING ⚠️ /content/drive/MyDrive/Yolov8/data/train/images/0777838554ecb1eb_jpg.rf.iPYXq2VyMllb4wmHbOmx.jpg: ignoring corrupt image/label: Label class 300 exceeds dataset class count 32. Possible class labels are 0-31
# train: WARNING ⚠️ /content/drive/MyDrive/Yolov8/data/train/images/07dfa70d0dfdf4e8_jpg.rf.3c08eaa4c5daa64b0072666a5e1cb090.jpg: ignoring corrupt image/label: Label class 300 exceeds dataset class count 32. Possible class labels are 0-31
# train: WARNING ⚠️ /content/drive/MyDrive/Yolov8/data/train/images/07dfa70d0dfdf4e8_jpg.rf.XuHXFyNdWJ2thHIlo1Z2.jpg: ignoring corrupt image/label: Label class 300 exceeds dataset class count 32. Possible class labels are 0-31
# train: WARNING ⚠️ /content/drive/MyDrive/Yolov8/data/train/images/089cc41a901b2653_jpg.rf.6743a24c01af44063b9c1968d6402f52.jpg: ignoring corrupt image/label: Label class 300 exceeds dataset class count 32. Possible class labels are 0-31
# train: WARNING ⚠️ /content/drive/MyDrive/Yolov8/data/train/images/089cc41a901b2653_jpg.rf.d86qKnK017K3pSWOEpdb.jpg: ignoring corrupt image/label: Label class 300 exceeds dataset class count 32. Possible class labels are 0-31
# train: WARNING ⚠️ /content/drive/MyDrive/Yolov8/data/train/images/08ebb1106c5f4799_jpg.rf.7ce43293a263c07c84a9c894f5caba87.jpg: ignoring corrupt image/label: Label class 300 exceeds dataset class count 32. Possible class labels are 0-31
# train: WARNING ⚠️ /content/drive/MyDrive/Yolov8/data/train/images/08ebb1106c5f4799_jpg.rf.NhEpevpClnnaJ1dYEL76.jpg: ignoring corrupt image/label: Label class 300 exceeds dataset class count 32. Possible class labels are 0-31
# train: WARNING ⚠️ /content/drive/MyDrive/Yolov8/data/train/images/094a36746383c2c9_jpg.rf.WsClMrSP8ZzTrei6Ef3y.jpg: ignoring corrupt image/label: Label class 300 exceeds dataset class count 32. Possible class labels are 0-31
# train: WARNING ⚠️ /content/drive/MyDrive/Yolov8/data/train/images/094a36746383c2c9_jpg.rf.adac28dd027835ae6bd5d92c6411f7ee.jpg: ignoring corrupt image/label: Label class 300 exceeds dataset class count 32. Possible class labels are 0-31
# train: WARNING ⚠️ /content/drive/MyDrive/Yolov8/data/train/images/09acb63accd06236_jpg.rf.6aDJNzlOrZfQZWhxZBV5.jpg: ignoring corrupt image/label: Label class 300 exceeds dataset class count 32. Possible class labels are 0-31
# train: WARNING ⚠️ /content/drive/MyDrive/Yolov8/data/train/images/09acb63accd06236_jpg.rf.fd5e4ac7a031350fb8e7b0d75bc93017.jpg: ignoring corrupt image/label: Label class 300 exceeds dataset class count 32. Possible class labels are 0-31
# train: WARNING ⚠️ /content/drive/MyDrive/Yolov8/data/train/images/09fd3f0199f2be7e_jpg.rf.1NoHW56IuJhRAiX5KW2H.jpg: ignoring corrupt image/label: Label class 300 exceeds dataset class count 32. Possible class labels are 0-31
# train: WARNING ⚠️ /content/drive/MyDrive/Yolov8/data/train/images/09fd3f0199f2be7e_jpg.rf.afd5e30f9d5d3cae89ecd8aafec6b7f1.jpg: ignoring corrupt image/label: Label class 300 exceeds dataset class count 32. Possible class labels are 0-31
# train: WARNING ⚠️ /content/drive/MyDrive/Yolov8/data/train/images/0a03d85b3dcb2a1b_jpg.rf.a00ac9c0b1e0178bd393f049593c73c6.jpg: ignoring corrupt image/label: Label class 300 exceeds dataset class count 32. Possible class labels are 0-31
# train: WARNING ⚠️ /content/drive/MyDrive/Yolov8/data/train/images/0a03d85b3dcb2a1b_jpg.rf.gAb723jHV4bglgt4HcyG.jpg: ignoring corrupt image/label: Label class 300 exceeds dataset class count 32. Possible class labels are 0-31
# train: WARNING ⚠️ /content/drive/MyDrive/Yolov8/data/train/images/0a56ee41a72480bc_jpg.rf.dbd67f25dc488d617d0b01d65de1584b.jpg: ignoring corrupt image/label: Label class 300 exceeds dataset class count 32. Possible class labels are 0-31
# train: WARNING ⚠️ /content/drive/MyDrive/Yolov8/data/train/images/0a56ee41a72480bc_jpg.rf.k0G8JC1qya6UiWGHtQK3.jpg: ignoring corrupt image/label: Label class 300 exceeds dataset class count 32. Possible class labels are 0-31
# train: WARNING ⚠️ /content/drive/MyDrive/Yolov8/data/train/images/0b35c604f8a87bd0_jpg.rf.0771220380bd5aa3d252ce58471bf2c7.jpg: ignoring corrupt image/label: Label class 300 exceeds dataset class count 32. Possible class labels are 0-31
# train: WARNING ⚠️ /content/drive/MyDrive/Yolov8/data/train/images/0b35c604f8a87bd0_jpg.rf.KMe69WjuxHI5xqZLXJfu.jpg: ignoring corrupt image/label: Label class 300 exceeds dataset class count 32. Possible class labels are 0-31
# train: WARNING ⚠️ /content/drive/MyDrive/Yolov8/data/train/images/0ba56949c8eb973e_jpg.rf.ff4a847a18df3833d18cc9d2497af55b.jpg: ignoring corrupt image/label: Label class 300 exceeds dataset class count 32. Possible class labels are 0-31
# train: WARNING ⚠️ /content/drive/MyDrive/Yolov8/data/train/images/0ba56949c8eb973e_jpg.rf.fj8T7A1fJkOPja4rYRS5.jpg: ignoring corrupt image/label: Label class 300 exceeds dataset class count 32. Possible class labels are 0-31
# train: WARNING ⚠️ /content/drive/MyDrive/Yolov8/data/train/images/0c5138e15c71f741_jpg.rf.KTxRFMsDGLvRWwg9Em64.jpg: ignoring corrupt image/label: Label class 300 exceeds dataset class count 32. Possible class labels are 0-31
# train: WARNING ⚠️ /content/drive/MyDrive/Yolov8/data/train/images/0c5138e15c71f741_jpg.rf.f1dddbc942fd2fa7fac0faefabf3486d.jpg: ignoring corrupt image/label: Label class 300 exceeds dataset class count 32. Possible class labels are 0-31
# train: WARNING ⚠️ /content/drive/MyDrive/Yolov8/data/train/images/0ca61e55ccf257ba_jpg.rf.83e309021a0dba2861bb3e99824d52be.jpg: ignoring corrupt image/label: Label class 300 exceeds dataset class count 32. Possible class labels are 0-31
# train: WARNING ⚠️ /content/drive/MyDrive/Yolov8/data/train/images/0ca61e55ccf257ba_jpg.rf.yVnPtUkAjIzk3ZdBSs6q.jpg: ignoring corrupt image/label: Label class 300 exceeds dataset class count 32. Possible class labels are 0-31
# train: WARNING ⚠️ /content/drive/MyDrive/Yolov8/data/train/images/0d829bbd335fe81c_jpg.rf.A2e7sSyZFbUPARnqx7Hp.jpg: ignoring corrupt image/label: Label class 300 exceeds dataset class count 32. Possible class labels are 0-31
# train: WARNING ⚠️ /content/drive/MyDrive/Yolov8/data/train/images/0d829bbd335fe81c_jpg.rf.c2a5859613b3f250d19926ba3fb0b22e.jpg: ignoring corrupt image/label: Label class 300 exceeds dataset class count 32. Possible class labels are 0-31
# train: WARNING ⚠️ /content/drive/MyDrive/Yolov8/data/train/images/0da0ba0e59845f96_jpg.rf.1e971f58853bc9f66b60785fd0a39791.jpg: ignoring corrupt image/label: Label class 300 exceeds dataset class count 32. Possible class labels are 0-31
# train: WARNING ⚠️ /content/drive/MyDrive/Yolov8/data/train/images/0da0ba0e59845f96_jpg.rf.pspJkFPXlBknp0LaQUrr.jpg: ignoring corrupt image/label: Label class 300 exceeds dataset class count 32. Possible class labels are 0-31
# train: WARNING ⚠️ /content/drive/MyDrive/Yolov8/data/train/images/0dc6d85a2ba0a534_jpg.rf.798b518c51dafb4c4b87ebc4753089ce.jpg: ignoring corrupt image/label: Label class 300 exceeds dataset class count 32. Possible class labels are 0-31
# train: WARNING ⚠️ /content/drive/MyDrive/Yolov8/data/train/images/0dc6d85a2ba0a534_jpg.rf.VzZEm1gYQCNHsenfKQc6.jpg: ignoring corrupt image/label: Label class 300 exceeds dataset class count 32. Possible class labels are 0-31
# train: WARNING ⚠️ /content/drive/MyDrive/Yolov8/data/train/images/0dddb5e2bc416a16_jpg.rf.5251d5e30ac2b063ecc31284d512c8c1.jpg: ignoring corrupt image/label: Label class 300 exceeds dataset class count 32. Possible class labels are 0-31
# train: WARNING ⚠️ /content/drive/MyDrive/Yolov8/data/train/images/0dddb5e2bc416a16_jpg.rf.LJYWxsjsJb3FcduYHowG.jpg: ignoring corrupt image/label: Label class 300 exceeds dataset class count 32. Possible class labels are 0-31
# train: WARNING ⚠️ /content/drive/MyDrive/Yolov8/data/train/images/0df5a680a412fa0b_jpg.rf.6f4eb25b75de66998570ad6e54aef165.jpg: ignoring corrupt image/label: Label class 300 exceeds dataset class count 32. Possible class labels are 0-31
# train: WARNING ⚠️ /content/drive/MyDrive/Yolov8/data/train/images/0df5a680a412fa0b_jpg.rf.TAvwaNBqf1CxVWb2bgXP.jpg: ignoring corrupt image/label: Label class 300 exceeds dataset class count 32. Possible class labels are 0-31
# train: WARNING ⚠️ /content/drive/MyDrive/Yolov8/data/train/images/0ebb654be1697247_jpg.rf.4PgyE4UaSZWY46uuYR6d.jpg: ignoring corrupt image/label: Label class 300 exceeds dataset class count 32. Possible class labels are 0-31
# train: WARNING ⚠️ /content/drive/MyDrive/Yolov8/data/train/images/0ebb654be1697247_jpg.rf.abbc5823dfcfda731702c580ed4a18b1.jpg: ignoring corrupt image/label: Label class 300 exceeds dataset class count 32. Possible class labels are 0-31
# train: WARNING ⚠️ /content/drive/MyDrive/Yolov8/data/train/images/0f26dd755f4b5ab6_jpg.rf.cebbe00b82a67f82a870052baa321ea3.jpg: ignoring corrupt image/label: Label class 300 exceeds dataset class count 32. Possible class labels are 0-31
# train: WARNING ⚠️ /content/drive/MyDrive/Yolov8/data/train/images/0f26dd755f4b5ab6_jpg.rf.e2BrVvcW749syaWYOa4Q.jpg: ignoring corrupt image/label: Label class 300 exceeds dataset class count 32. Possible class labels are 0-31
# train: WARNING ⚠️ /content/drive/MyDrive/Yolov8/data/train/images/0f7f3b82ff9db6e8_jpg.rf.77bd34603ccff62cac2773efbf128032.jpg: ignoring corrupt image/label: Label class 300 exceeds dataset class count 32. Possible class labels are 0-31
# train: WARNING ⚠️ /content/drive/MyDrive/Yolov8/data/train/images/0f7f3b82ff9db6e8_jpg.rf.A3TlZJRSD6fLCAAK4JZp.jpg: ignoring corrupt image/label: Label class 300 exceeds dataset class count 32. Possible class labels are 0-31
# train: WARNING ⚠️ /content/drive/MyDrive/Yolov8/data/train/images/0ff18bf912a38470_jpg.rf.6d0b73328b83ee17005180d6db9b27fe.jpg: ignoring corrupt image/label: Label class 300 exceeds dataset class count 32. Possible class labels are 0-31
# train: WARNING ⚠️ /content/drive/MyDrive/Yolov8/data/train/images/0ff18bf912a38470_jpg.rf.EMxNilgSVL7O0MH03cWw.jpg: ignoring corrupt image/label: Label class 300 exceeds dataset class count 32. Possible class labels are 0-31
# train: WARNING ⚠️ /content/drive/MyDrive/Yolov8/data/train/images/1000_F_195178134_qAqsFrUXERMCEdqKXECbZbruJLi7OUf4_jpg.rf.9b9b7e6dd4a9d87eadb6edbbe3293f92.jpg: ignoring corrupt image/label: Label class 100 exceeds dataset class count 32. Possible class labels are 0-31
# train: WARNING ⚠️ /content/drive/MyDrive/Yolov8/data/train/images/107109052-1661390707370-gettyimages-1241869545-AFP_32EB7NL_jpeg.rf.b65370c19ba87fa5708d549e380fa3b3.jpg: ignoring corrupt image/label: Label class 100 exceeds dataset class count 32. Possible class labels are 0-31
# train: WARNING ⚠️ /content/drive/MyDrive/Yolov8/data/train/images/10824aeb7449a206_jpg.rf.8VBXGYzGcfjFqxT1XAL6.jpg: ignoring corrupt image/label: Label class 300 exceeds dataset class count 32. Possible class labels are 0-31
# train: WARNING ⚠️ /content/drive/MyDrive/Yolov8/data/train/images/10824aeb7449a206_jpg.rf.fb9c1fc359a8897a11adcf26102e6da7.jpg: ignoring corrupt image/label: Label class 300 exceeds dataset class count 32. Possible class labels are 0-31
# train: WARNING ⚠️ /content/drive/MyDrive/Yolov8/data/train/images/10e8132f183fcc3e_jpg.rf.bd65cc173ce6f95cfd720b46a04ab9b3.jpg: ignoring corrupt image/label: Label class 300 exceeds dataset class count 32. Possible class labels are 0-31
# train: WARNING ⚠️ /content/drive/MyDrive/Yolov8/data/train/images/10e8132f183fcc3e_jpg.rf.nG1G7sDMLXpxGzXxMCPn.jpg: ignoring corrupt image/label: Label class 300 exceeds dataset class count 32. Possible class labels are 0-31
# train: WARNING ⚠️ /content/drive/MyDrive/Yolov8/data/train/images/1238d5f7b2820007_jpg.rf.87d6c704a664f3c0ce592d7408ef1c8d.jpg: ignoring corrupt image/label: Label class 300 exceeds dataset class count 32. Possible class labels are 0-31
# train: WARNING ⚠️ /content/drive/MyDrive/Yolov8/data/train/images/1238d5f7b2820007_jpg.rf.BLGDJElnJ0staQy433ct.jpg: ignoring corrupt image/label: Label class 300 exceeds dataset class count 32. Possible class labels are 0-31
# train: WARNING ⚠️ /content/drive/MyDrive/Yolov8/data/train/images/124428493-low-angle-of-car-in-front-of-pedestrian-crossing-and-walking-boy-with-smartphone_jpg.rf.e6bc89c89a99c19b386731c8e9b7cee4.jpg: ignoring corrupt image/label: Label class 100 exceeds dataset class count 32. Possible class labels are 0-31
# train: WARNING ⚠️ /content/drive/MyDrive/Yolov8/data/train/images/13ea89974fc5e30b_jpg.rf.5f030335718610642432bb4f65e23b74.jpg: ignoring corrupt image/label: Label class 300 exceeds dataset class count 32. Possible class labels are 0-31
# train: WARNING ⚠️ /content/drive/MyDrive/Yolov8/data/train/images/13ea89974fc5e30b_jpg.rf.DhTyqTlIk0J2BqTZ2lgb.jpg: ignoring corrupt image/label: Label class 300 exceeds dataset class count 32. Possible class labels are 0-31
# train: WARNING ⚠️ /content/drive/MyDrive/Yolov8/data/train/images/1781ceeba365928b_jpg.rf.BeJOJjojkNZXLd3W7yur.jpg: ignoring corrupt image/label: Label class 300 exceeds dataset class count 32. Possible class labels are 0-31
# train: WARNING ⚠️ /content/drive/MyDrive/Yolov8/data/train/images/1781ceeba365928b_jpg.rf.b658668ccefc5b053a17a307e0cd6c11.jpg: ignoring corrupt image/label: Label class 300 exceeds dataset class count 32. Possible class labels are 0-31
# train: WARNING ⚠️ /content/drive/MyDrive/Yolov8/data/train/images/179795f3d2775d7c_jpg.rf.24e0b9a601bd283bf74631f1b4378b2d.jpg: ignoring corrupt image/label: Label class 300 exceeds dataset class count 32. Possible class labels are 0-31
# train: WARNING ⚠️ /content/drive/MyDrive/Yolov8/data/train/images/179795f3d2775d7c_jpg.rf.gjidZuYXo9VrpckgZRJd.jpg: ignoring corrupt image/label: Label class 300 exceeds dataset class count 32. Possible class labels are 0-31
# train: WARNING ⚠️ /content/drive/MyDrive/Yolov8/data/train/images/17d99b801acab230_jpg.rf.OoD9VMNX3qJJVo4MtWBX.jpg: ignoring corrupt image/label: Label class 300 exceeds dataset class count 32. Possible class labels are 0-31
# train: WARNING ⚠️ /content/drive/MyDrive/Yolov8/data/train/images/17d99b801acab230_jpg.rf.f074b5569af3bf221a16764ec269eee6.jpg: ignoring corrupt image/label: Label class 300 exceeds dataset class count 32. Possible class labels are 0-31
# train: WARNING ⚠️ /content/drive/MyDrive/Yolov8/data/train/images/190614104153-07-shibuya-crossing-restricted_jpg.rf.0abeb072c3c9d7c33aadbaa065e807f2.jpg: ignoring corrupt image/label: Label class 100 exceeds dataset class count 32. Possible class labels are 0-31
# train: WARNING ⚠️ /content/drive/MyDrive/Yolov8/data/train/images/190625_04_CityMisc_HD_18_small_jpg.rf.a672148d548367908fbd6a2679cbceea.jpg: ignoring corrupt image/label: Label class 100 exceeds dataset class count 32. Possible class labels are 0-31
# train: WARNING ⚠️ /content/drive/MyDrive/Yolov8/data/train/images/1987e409c66239ab_jpg.rf.d7678b63733b53ef519f5b2b4929b9b3.jpg: ignoring corrupt image/label: Label class 300 exceeds dataset class count 32. Possible class labels are 0-31
# train: WARNING ⚠️ /content/drive/MyDrive/Yolov8/data/train/images/1987e409c66239ab_jpg.rf.koSyKVgWjx4eplEqXo9R.jpg: ignoring corrupt image/label: Label class 300 exceeds dataset class count 32. Possible class labels are 0-31
# train: WARNING ⚠️ /content/drive/MyDrive/Yolov8/data/train/images/19ed71affe514276_jpg.rf.9ced048a08b368f1b31440320c254e1d.jpg: ignoring corrupt image/label: Label class 300 exceeds dataset class count 32. Possible class labels are 0-31
# train: WARNING ⚠️ /content/drive/MyDrive/Yolov8/data/train/images/19ed71affe514276_jpg.rf.MaXS95uHSrJkcxQNoB9U.jpg: ignoring corrupt image/label: Label class 300 exceeds dataset class count 32. Possible class labels are 0-31
# train: WARNING ⚠️ /content/drive/MyDrive/Yolov8/data/train/images/1b43e569dfb2d630_jpg.rf.3mxD27XM3EEYlgrpJVWa.jpg: ignoring corrupt image/label: Label class 300 exceeds dataset class count 32. Possible class labels are 0-31
# train: WARNING ⚠️ /content/drive/MyDrive/Yolov8/data/train/images/1b43e569dfb2d630_jpg.rf.686424f841c358ea25f846960f257272.jpg: ignoring corrupt image/label: Label class 300 exceeds dataset class count 32. Possible class labels are 0-31
# train: WARNING ⚠️ /content/drive/MyDrive/Yolov8/data/train/images/1b9c5720266a6140_jpg.rf.Z5naVkKrgkjWf9dGUBX8.jpg: ignoring corrupt image/label: Label class 300 exceeds dataset class count 32. Possible class labels are 0-31
# train: WARNING ⚠️ /content/drive/MyDrive/Yolov8/data/train/images/1b9c5720266a6140_jpg.rf.a8186fcc7a9506f790202a5fa166c23c.jpg: ignoring corrupt image/label: Label class 300 exceeds dataset class count 32. Possible class labels are 0-31
# train: WARNING ⚠️ /content/drive/MyDrive/Yolov8/data/train/images/1c64bff45216007f_jpg.rf.00472dc1dcd49262a84274a23e3a1999.jpg: ignoring corrupt image/label: Label class 300 exceeds dataset class count 32. Possible class labels are 0-31
# train: WARNING ⚠️ /content/drive/MyDrive/Yolov8/data/train/images/1c64bff45216007f_jpg.rf.FxyEhepTOcDM9UDmgNpF.jpg: ignoring corrupt image/label: Label class 300 exceeds dataset class count 32. Possible class labels are 0-31
# train: WARNING ⚠️ /content/drive/MyDrive/Yolov8/data/train/images/1ce4f78534c54bc2_jpg.rf.6576199f347ddbf94b17e3618e3036d5.jpg: ignoring corrupt image/label: Label class 300 exceeds dataset class count 32. Possible class labels are 0-31
# train: WARNING ⚠️ /content/drive/MyDrive/Yolov8/data/train/images/1ce4f78534c54bc2_jpg.rf.s2ZOzXrpO2r5xhUeUaia.jpg: ignoring corrupt image/label: Label class 300 exceeds dataset class count 32. Possible class labels are 0-31
# train: WARNING ⚠️ /content/drive/MyDrive/Yolov8/data/train/images/1d26ac4c9e98acc1_jpg.rf.8641817caed666f7a64ce92da5048955.jpg: ignoring corrupt image/label: Label class 300 exceeds dataset class count 32. Possible class labels are 0-31
# train: WARNING ⚠️ /content/drive/MyDrive/Yolov8/data/train/images/1d26ac4c9e98acc1_jpg.rf.VzquRYAydWgUVdviiPv7.jpg: ignoring corrupt image/label: Label class 300 exceeds dataset class count 32. Possible class labels are 0-31
# train: WARNING ⚠️ /content/drive/MyDrive/Yolov8/data/train/images/1d58456f6d5e9498_jpg.rf.99e8a490fd6b36de59d1548e7e660c59.jpg: ignoring corrupt image/label: Label class 300 exceeds dataset class count 32. Possible class labels are 0-31
# train: WARNING ⚠️ /content/drive/MyDrive/Yolov8/data/train/images/1d58456f6d5e9498_jpg.rf.Ha2BDbyjAcYLK6AndEGv.jpg: ignoring corrupt image/label: Label class 300 exceeds dataset class count 32. Possible class labels are 0-31
# train: WARNING ⚠️ /content/drive/MyDrive/Yolov8/data/train/images/1d9e2bdfc0ef4f35_jpg.rf.LR0ER7AipXMkoeSIX2zY.jpg: ignoring corrupt image/label: Label class 300 exceeds dataset class count 32. Possible class labels are 0-31
# train: WARNING ⚠️ /content/drive/MyDrive/Yolov8/data/train/images/1d9e2bdfc0ef4f35_jpg.rf.d187af648a43d1ccdd62259decd41ad7.jpg: ignoring corrupt image/label: Label class 300 exceeds dataset class count 32. Possible class labels are 0-31
# train: WARNING ⚠️ /content/drive/MyDrive/Yolov8/data/train/images/1dbc8d811c800ef7_jpg.rf.0fe7faaa475da74452fb74b9883f7088.jpg: ignoring corrupt image/label: Label class 300 exceeds dataset class count 32. Possible class labels are 0-31
# train: WARNING ⚠️ /content/drive/MyDrive/Yolov8/data/train/images/1dbc8d811c800ef7_jpg.rf.5X5S6sH5woR5ul2ERKfy.jpg: ignoring corrupt image/label: Label class 300 exceeds dataset class count 32. Possible class labels are 0-31
# train: WARNING ⚠️ /content/drive/MyDrive/Yolov8/data/train/images/1e668423ae32ce6f_jpg.rf.70kBZq8qBqHjRPMoyl5I.jpg: ignoring corrupt image/label: Label class 300 exceeds dataset class count 32. Possible class labels are 0-31
# train: WARNING ⚠️ /content/drive/MyDrive/Yolov8/data/train/images/1e668423ae32ce6f_jpg.rf.8fc1bcf11c1a5bb1747a7ec8b3a16746.jpg: ignoring corrupt image/label: Label class 300 exceeds dataset class count 32. Possible class labels are 0-31
# train: WARNING ⚠️ /content/drive/MyDrive/Yolov8/data/train/images/1f0ce568a7da5d78_jpg.rf.7e00114aae9d57b5a6ab4201eec63267.jpg: ignoring corrupt image/label: Label class 300 exceeds dataset class count 32. Possible class labels are 0-31
# train: WARNING ⚠️ /content/drive/MyDrive/Yolov8/data/train/images/1f0ce568a7da5d78_jpg.rf.ve5JU4DFxXTtyub25Rw9.jpg: ignoring corrupt image/label: Label class 300 exceeds dataset class count 32. Possible class labels are 0-31
# train: WARNING ⚠️ /content/drive/MyDrive/Yolov8/data/train/images/1f73c7a77643e224_jpg.rf.3b9866bb17c5521d958b16f9e2002118.jpg: ignoring corrupt image/label: Label class 300 exceeds dataset class count 32. Possible class labels are 0-31
# train: WARNING ⚠️ /content/drive/MyDrive/Yolov8/data/train/images/1f73c7a77643e224_jpg.rf.bBv2FpQK1LRbWbSe2SbR.jpg: ignoring corrupt image/label: Label class 300 exceeds dataset class count 32. Possible class labels are 0-31
# train: WARNING ⚠️ /content/drive/MyDrive/Yolov8/data/train/images/1fc8576317033787_jpg.rf.8929803280ce2a54ce1c6b40e0e9098b.jpg: ignoring corrupt image/label: Label class 300 exceeds dataset class count 32. Possible class labels are 0-31
# train: WARNING ⚠️ /content/drive/MyDrive/Yolov8/data/train/images/1fc8576317033787_jpg.rf.KKBtuw70uV5JaoSPC06n.jpg: ignoring corrupt image/label: Label class 300 exceeds dataset class count 32. Possible class labels are 0-31
# train: WARNING ⚠️ /content/drive/MyDrive/Yolov8/data/train/images/1fd80240046ef704_jpg.rf.5972f63ece5a4759973eeee7d391bee2.jpg: ignoring corrupt image/label: Label class 300 exceeds dataset class count 32. Possible class labels are 0-31
# train: WARNING ⚠️ /content/drive/MyDrive/Yolov8/data/train/images/1fd80240046ef704_jpg.rf.sjncsXJ8QTNC7Iweo2bL.jpg: ignoring corrupt image/label: Label class 300 exceeds dataset class count 32. Possible class labels are 0-31
# train: WARNING ⚠️ /content/drive/MyDrive/Yolov8/data/train/images/20514cfccbb4a2ab_jpg.rf.1rV4IrjXJWiwYzuYnfQc.jpg: ignoring corrupt image/label: Label class 300 exceeds dataset class count 32. Possible class labels are 0-31
# train: WARNING ⚠️ /content/drive/MyDrive/Yolov8/data/train/images/20514cfccbb4a2ab_jpg.rf.6b5909905e17e5fae50d43d7d53e9d9f.jpg: ignoring corrupt image/label: Label class 300 exceeds dataset class count 32. Possible class labels are 0-31
# train: WARNING ⚠️ /content/drive/MyDrive/Yolov8/data/train/images/20c199ea745dd0de_jpg.rf.d53165d0bd1f118877b90c1eb2a11e79.jpg: ignoring corrupt image/label: Label class 300 exceeds dataset class count 32. Possible class labels are 0-31
# train: WARNING ⚠️ /content/drive/MyDrive/Yolov8/data/train/images/20c199ea745dd0de_jpg.rf.tzuHsGv2CfCWjjFgGpZ3.jpg: ignoring corrupt image/label: Label class 300 exceeds dataset class count 32. Possible class labels are 0-31
# train: WARNING ⚠️ /content/drive/MyDrive/Yolov8/data/train/images/20db335ae6d55102_jpg.rf.3e6cfef62ff9a25e20e024e40b3d74d4.jpg: ignoring corrupt image/label: Label class 300 exceeds dataset class count 32. Possible class labels are 0-31
# train: WARNING ⚠️ /content/drive/MyDrive/Yolov8/data/train/images/20db335ae6d55102_jpg.rf.tMNlMMAheaGznNxJxJAy.jpg: ignoring corrupt image/label: Label class 300 exceeds dataset class count 32. Possible class labels are 0-31
# train: WARNING ⚠️ /content/drive/MyDrive/Yolov8/data/train/images/210112c7c8085350_jpg.rf.2A3UPBzlVqeeaf1Ui3j4.jpg: ignoring corrupt image/label: Label class 300 exceeds dataset class count 32. Possible class labels are 0-31
# train: WARNING ⚠️ /content/drive/MyDrive/Yolov8/data/train/images/210112c7c8085350_jpg.rf.2b27d2da50f374c5a0e5438f85106d1e.jpg: ignoring corrupt image/label: Label class 300 exceeds dataset class count 32. Possible class labels are 0-31
# train: WARNING ⚠️ /content/drive/MyDrive/Yolov8/data/train/images/214e9577f1bc9e1a_jpg.rf.9a99234bb710ce56feec21b827ced326.jpg: ignoring corrupt image/label: Label class 300 exceeds dataset class count 32. Possible class labels are 0-31
# train: WARNING ⚠️ /content/drive/MyDrive/Yolov8/data/train/images/214e9577f1bc9e1a_jpg.rf.Sg6TcWCCd4fVWPyssDbb.jpg: ignoring corrupt image/label: Label class 300 exceeds dataset class count 32. Possible class labels are 0-31
# train: WARNING ⚠️ /content/drive/MyDrive/Yolov8/data/train/images/230823605bf60c37_jpg.rf.d4caabb0edfc6a41a72b1c590b868f47.jpg: ignoring corrupt image/label: Label class 300 exceeds dataset class count 32. Possible class labels are 0-31
# train: WARNING ⚠️ /content/drive/MyDrive/Yolov8/data/train/images/230823605bf60c37_jpg.rf.w5PtSkESUfxwB6p4RVUy.jpg: ignoring corrupt image/label: Label class 300 exceeds dataset class count 32. Possible class labels are 0-31
# train: WARNING ⚠️ /content/drive/MyDrive/Yolov8/data/train/images/2364e615592f1fe0_jpg.rf.ddcd0c745851200e6a76bd05ace6ccc0.jpg: ignoring corrupt image/label: Label class 300 exceeds dataset class count 32. Possible class labels are 0-31
# train: WARNING ⚠️ /content/drive/MyDrive/Yolov8/data/train/images/2364e615592f1fe0_jpg.rf.ezfbooTgGswcb9pak2Ka.jpg: ignoring corrupt image/label: Label class 300 exceeds dataset class count 32. Possible class labels are 0-31
# train: WARNING ⚠️ /content/drive/MyDrive/Yolov8/data/train/images/2430d5e7d680b683_jpg.rf.82c5a0ed4e72587030cac00ebdb687e0.jpg: ignoring corrupt image/label: Label class 300 exceeds dataset class count 32. Possible class labels are 0-31
# train: WARNING ⚠️ /content/drive/MyDrive/Yolov8/data/train/images/2430d5e7d680b683_jpg.rf.OyBZncJVddKt93HJUo0d.jpg: ignoring corrupt image/label: Label class 300 exceeds dataset class count 32. Possible class labels are 0-31
# train: WARNING ⚠️ /content/drive/MyDrive/Yolov8/data/train/images/26263aba764cf3ed_jpg.rf.0EnVZpaR9duphdjXXiDb.jpg: ignoring corrupt image/label: Label class 300 exceeds dataset class count 32. Possible class labels are 0-31
# train: WARNING ⚠️ /content/drive/MyDrive/Yolov8/data/train/images/26263aba764cf3ed_jpg.rf.a14e89d811816f76b883b6aac67559a8.jpg: ignoring corrupt image/label: Label class 300 exceeds dataset class count 32. Possible class labels are 0-31
# train: WARNING ⚠️ /content/drive/MyDrive/Yolov8/data/train/images/26513c95488eebdd_jpg.rf.0Ngs4rbrTpLkJdIC6tzs.jpg: ignoring corrupt image/label: Label class 300 exceeds dataset class count 32. Possible class labels are 0-31
# train: WARNING ⚠️ /content/drive/MyDrive/Yolov8/data/train/images/26513c95488eebdd_jpg.rf.5772ab3ff445c2586e1aec82fc2298e3.jpg: ignoring corrupt image/label: Label class 300 exceeds dataset class count 32. Possible class labels are 0-31
# train: WARNING ⚠️ /content/drive/MyDrive/Yolov8/data/train/images/26775ec6cdcdbc9d_jpg.rf.790f2b5b847fa269c75fb3859dc0a78a.jpg: ignoring corrupt image/label: Label class 300 exceeds dataset class count 32. Possible class labels are 0-31
# train: WARNING ⚠️ /content/drive/MyDrive/Yolov8/data/train/images/26775ec6cdcdbc9d_jpg.rf.SrxQQ6ss3w30smaf4U7W.jpg: ignoring corrupt image/label: Label class 300 exceeds dataset class count 32. Possible class labels are 0-31
# train: WARNING ⚠️ /content/drive/MyDrive/Yolov8/data/train/images/26a70b16b74ea019_jpg.rf.b45c2e3d28ca44690d56eefca282f2c6.jpg: ignoring corrupt image/label: Label class 300 exceeds dataset class count 32. Possible class labels are 0-31
# train: WARNING ⚠️ /content/drive/MyDrive/Yolov8/data/train/images/26a70b16b74ea019_jpg.rf.hsyD9T3gu9y6PaMKka9Y.jpg: ignoring corrupt image/label: Label class 300 exceeds dataset class count 32. Possible class labels are 0-31
# train: WARNING ⚠️ /content/drive/MyDrive/Yolov8/data/train/images/27fed64f6e8e0fb1_jpg.rf.365f036b3c5c98218829c2b839a9bbe9.jpg: ignoring corrupt image/label: Label class 300 exceeds dataset class count 32. Possible class labels are 0-31
# train: WARNING ⚠️ /content/drive/MyDrive/Yolov8/data/train/images/27fed64f6e8e0fb1_jpg.rf.b50KniIs94RySOnXJ9Un.jpg: ignoring corrupt image/label: Label class 300 exceeds dataset class count 32. Possible class labels are 0-31
# train: WARNING ⚠️ /content/drive/MyDrive/Yolov8/data/train/images/28d3c263a66b08f5_jpg.rf.87119d53d243fe3089970774280d5d73.jpg: ignoring corrupt image/label: Label class 300 exceeds dataset class count 32. Possible class labels are 0-31
# train: WARNING ⚠️ /content/drive/MyDrive/Yolov8/data/train/images/28d3c263a66b08f5_jpg.rf.PscJGYNL7Kczh6fTHzfD.jpg: ignoring corrupt image/label: Label class 300 exceeds dataset class count 32. Possible class labels are 0-31
# train: WARNING ⚠️ /content/drive/MyDrive/Yolov8/data/train/images/28ed22d3254867a6_jpg.rf.5ef4ac6f5b21cb29a79855d67d16600d.jpg: ignoring corrupt image/label: Label class 300 exceeds dataset class count 32. Possible class labels are 0-31
# train: WARNING ⚠️ /content/drive/MyDrive/Yolov8/data/train/images/28ed22d3254867a6_jpg.rf.HbFne5hOHufTh5oNhjbX.jpg: ignoring corrupt image/label: Label class 300 exceeds dataset class count 32. Possible class labels are 0-31
# train: WARNING ⚠️ /content/drive/MyDrive/Yolov8/data/train/images/2a565728597f77d4_jpg.rf.1231296a821f84bdb13a26525627dd12.jpg: ignoring corrupt image/label: Label class 300 exceeds dataset class count 32. Possible class labels are 0-31
# train: WARNING ⚠️ /content/drive/MyDrive/Yolov8/data/train/images/2a565728597f77d4_jpg.rf.fawkvGqw6EoJhpQFcYRV.jpg: ignoring corrupt image/label: Label class 300 exceeds dataset class count 32. Possible class labels are 0-31
# train: WARNING ⚠️ /content/drive/MyDrive/Yolov8/data/train/images/2b9ced539656ae78_jpg.rf.09375be44a0f433daca7f5d9d5a69aa1.jpg: ignoring corrupt image/label: Label class 300 exceeds dataset class count 32. Possible class labels are 0-31
# train: WARNING ⚠️ /content/drive/MyDrive/Yolov8/data/train/images/2b9ced539656ae78_jpg.rf.z1gYArZRpSVHNALKfiUl.jpg: ignoring corrupt image/label: Label class 300 exceeds dataset class count 32. Possible class labels are 0-31
# train: WARNING ⚠️ /content/drive/MyDrive/Yolov8/data/train/images/2bc6989e7421dc9d_jpg.rf.3bb48090000df048edfc8f37254c0efe.jpg: ignoring corrupt image/label: Label class 300 exceeds dataset class count 32. Possible class labels are 0-31
# train: WARNING ⚠️ /content/drive/MyDrive/Yolov8/data/train/images/2bc6989e7421dc9d_jpg.rf.GiL440iXDvnivl1PUm07.jpg: ignoring corrupt image/label: Label class 300 exceeds dataset class count 32. Possible class labels are 0-31
# train: WARNING ⚠️ /content/drive/MyDrive/Yolov8/data/train/images/2c22bcb9295eacdf_jpg.rf.Ffq2LsNEib2qyrQegkD5.jpg: ignoring corrupt image/label: Label class 300 exceeds dataset class count 32. Possible class labels are 0-31
# train: WARNING ⚠️ /content/drive/MyDrive/Yolov8/data/train/images/2c22bcb9295eacdf_jpg.rf.a9deea64a3f990fafb6c5307bf7f50fa.jpg: ignoring corrupt image/label: Label class 300 exceeds dataset class count 32. Possible class labels are 0-31
# train: WARNING ⚠️ /content/drive/MyDrive/Yolov8/data/train/images/2d31e0cd26889eaa_jpg.rf.26d7b1b63729dfebbc5db596fe59178f.jpg: ignoring corrupt image/label: Label class 300 exceeds dataset class count 32. Possible class labels are 0-31
# train: WARNING ⚠️ /content/drive/MyDrive/Yolov8/data/train/images/2d31e0cd26889eaa_jpg.rf.RGNDuae9QN5hXIpcFcWH.jpg: ignoring corrupt image/label: Label class 300 exceeds dataset class count 32. Possible class labels are 0-31
# train: WARNING ⚠️ /content/drive/MyDrive/Yolov8/data/train/images/2d499dab8c71a566_jpg.rf.70cfae41cb9799895a7f14be2faeb437.jpg: ignoring corrupt image/label: Label class 300 exceeds dataset class count 32. Possible class labels are 0-31
# train: WARNING ⚠️ /content/drive/MyDrive/Yolov8/data/train/images/2d499dab8c71a566_jpg.rf.dAfOH6Rjadb45ADmUOmq.jpg: ignoring corrupt image/label: Label class 300 exceeds dataset class count 32. Possible class labels are 0-31
# train: WARNING ⚠️ /content/drive/MyDrive/Yolov8/data/train/images/2d8f99d3e1b461fe_jpg.rf.ec60218a35f34e9e8b49905f97d01628.jpg: ignoring corrupt image/label: Label class 300 exceeds dataset class count 32. Possible class labels are 0-31
# train: WARNING ⚠️ /content/drive/MyDrive/Yolov8/data/train/images/2d8f99d3e1b461fe_jpg.rf.m2H7uQANnuUHuAM0oVTE.jpg: ignoring corrupt image/label: Label class 300 exceeds dataset class count 32. Possible class labels are 0-31
# train: WARNING ⚠️ /content/drive/MyDrive/Yolov8/data/train/images/2d94e4aa09c1c7de_jpg.rf.6a167278bce72167ecfaa3ff7a848ec9.jpg: ignoring corrupt image/label: Label class 300 exceeds dataset class count 32. Possible class labels are 0-31
# train: WARNING ⚠️ /content/drive/MyDrive/Yolov8/data/train/images/2d94e4aa09c1c7de_jpg.rf.PqpF5J0wmYBef380GjYT.jpg: ignoring corrupt image/label: Label class 300 exceeds dataset class count 32. Possible class labels are 0-31
# train: WARNING ⚠️ /content/drive/MyDrive/Yolov8/data/train/images/2e29dd7285110315_jpg.rf.22aaf637e168b3dc960eb35532e3ac1a.jpg: ignoring corrupt image/label: Label class 300 exceeds dataset class count 32. Possible class labels are 0-31
# ...
# val: WARNING ⚠️ /content/drive/MyDrive/Yolov8/data/valid/images/img-493_jpg.rf.bb58a09287078393b132cd2b68fe6f29.jpg: ignoring corrupt image/label: Label class 200 exceeds dataset class count 32. Possible class labels are 0-31
# val: WARNING ⚠️ /content/drive/MyDrive/Yolov8/data/valid/images/img-495_jpg.rf.3f61bcb802633686f9ce58fe78841711.jpg: ignoring corrupt image/label: Label class 200 exceeds dataset class count 32. Possible class labels are 0-31
# val: WARNING ⚠️ /content/drive/MyDrive/Yolov8/data/valid/images/img-497_jpg.rf.2c64d54e6604c392b9fc468079a62835.jpg: ignoring corrupt image/label: Label class 200 exceeds dataset class count 32. Possible class labels are 0-31
# val: WARNING ⚠️ /content/drive/MyDrive/Yolov8/data/valid/images/img-499_jpg.rf.8cbc7c8dba292bbadcc34ce63112514c.jpg: ignoring corrupt image/label: Label class 200 exceeds dataset class count 32. Possible class labels are 0-31
# val: WARNING ⚠️ /content/drive/MyDrive/Yolov8/data/valid/images/img-50_jpg.rf.d6c31e4e1a8a7cf2821589d31caca674.jpg: ignoring corrupt image/label: Label class 200 exceeds dataset class count 32. Possible class labels are 0-31
# val: WARNING ⚠️ /content/drive/MyDrive/Yolov8/data/valid/images/img-511_jpg.rf.94ceff8a653e0f0a77c23165b0c593f9.jpg: ignoring corrupt image/label: Label class 200 exceeds dataset class count 32. Possible class labels are 0-31
# val: WARNING ⚠️ /content/drive/MyDrive/Yolov8/data/valid/images/img-516_jpg.rf.d9bff40a3244096755225e1efa7dfeba.jpg: ignoring corrupt image/label: Label class 200 exceeds dataset class count 32. Possible class labels are 0-31
# val: WARNING ⚠️ /content/drive/MyDrive/Yolov8/data/valid/images/img-522_jpg.rf.19bb1d8b2dbde293dc2db61b5beb29db.jpg: ignoring corrupt image/label: Label class 200 exceeds dataset class count 32. Possible class labels are 0-31
# val: WARNING ⚠️ /content/drive/MyDrive/Yolov8/data/valid/images/img-528_jpg.rf.c63149b7ef386bf6460eaa2554fec266.jpg: ignoring corrupt image/label: Label class 200 exceeds dataset class count 32. Possible class labels are 0-31
# val: WARNING ⚠️ /content/drive/MyDrive/Yolov8/data/valid/images/img-529_jpg.rf.395bedb53c0403cfb0f83578d822b6b8.jpg: ignoring corrupt image/label: Label class 200 exceeds dataset class count 32. Possible class labels are 0-31
# val: WARNING ⚠️ /content/drive/MyDrive/Yolov8/data/valid/images/img-535_jpg.rf.669fb50bbde250434e606615f9a7a8fa.jpg: ignoring corrupt image/label: Label class 200 exceeds dataset class count 32. Possible class labels are 0-31
# val: WARNING ⚠️ /content/drive/MyDrive/Yolov8/data/valid/images/img-540_jpg.rf.ae97ce521cfe27b4be4048ce3639006f.jpg: ignoring corrupt image/label: Label class 200 exceeds dataset class count 32. Possible class labels are 0-31
# val: WARNING ⚠️ /content/drive/MyDrive/Yolov8/data/valid/images/img-541_jpg.rf.a93d4341d13182b1ba189ce4caac5b95.jpg: ignoring corrupt image/label: Label class 200 exceeds dataset class count 32. Possible class labels are 0-31
# val: WARNING ⚠️ /content/drive/MyDrive/Yolov8/data/valid/images/img-542_jpg.rf.77644450590746c96376f073e2160d29.jpg: ignoring corrupt image/label: Label class 200 exceeds dataset class count 32. Possible class labels are 0-31
# val: WARNING ⚠️ /content/drive/MyDrive/Yolov8/data/valid/images/img-543_jpg.rf.38f8a9ae642555e814236470bd45ca06.jpg: ignoring corrupt image/label: Label class 200 exceeds dataset class count 32. Possible class labels are 0-31
# val: WARNING ⚠️ /content/drive/MyDrive/Yolov8/data/valid/images/img-544_jpg.rf.1696075b72562916060477389b97635d.jpg: ignoring corrupt image/label: Label class 200 exceeds dataset class count 32. Possible class labels are 0-31
# val: WARNING ⚠️ /content/drive/MyDrive/Yolov8/data/valid/images/img-550_jpg.rf.73963e09241885e0b95e88ea797011c9.jpg: ignoring corrupt image/label: Label class 200 exceeds dataset class count 32. Possible class labels are 0-31
# val: WARNING ⚠️ /content/drive/MyDrive/Yolov8/data/valid/images/img-556_jpg.rf.1c89285dfe3675fd0e4a7958c48a7a87.jpg: ignoring corrupt image/label: Label class 200 exceeds dataset class count 32. Possible class labels are 0-31
# val: WARNING ⚠️ /content/drive/MyDrive/Yolov8/data/valid/images/img-558_jpg.rf.8ea5bd335e315b5c35f3f933216a2fe8.jpg: ignoring corrupt image/label: Label class 200 exceeds dataset class count 32. Possible class labels are 0-31
# val: WARNING ⚠️ /content/drive/MyDrive/Yolov8/data/valid/images/img-567_jpg.rf.7fcd2254ecf1d37fbfd8d8d4c83fcc90.jpg: ignoring corrupt image/label: Label class 200 exceeds dataset class count 32. Possible class labels are 0-31
# val: WARNING ⚠️ /content/drive/MyDrive/Yolov8/data/valid/images/img-586_jpg.rf.c599e62337598393ee94ecae83a5328a.jpg: ignoring corrupt image/label: Label class 200 exceeds dataset class count 32. Possible class labels are 0-31
# val: WARNING ⚠️ /content/drive/MyDrive/Yolov8/data/valid/images/img-591_jpg.rf.fa268af30a7118608f2149617dd18a96.jpg: ignoring corrupt image/label: Label class 200 exceeds dataset class count 32. Possible class labels are 0-31
# val: WARNING ⚠️ /content/drive/MyDrive/Yolov8/data/valid/images/img-596_jpg.rf.9b1ad14e1432c973fe3224c2ef8794c3.jpg: ignoring corrupt image/label: Label class 200 exceeds dataset class count 32. Possible class labels are 0-31
# val: WARNING ⚠️ /content/drive/MyDrive/Yolov8/data/valid/images/img-597_jpg.rf.4ed3cb021048833cff70c9a21abfece2.jpg: ignoring corrupt image/label: Label class 200 exceeds dataset class count 32. Possible class labels are 0-31
# val: WARNING ⚠️ /content/drive/MyDrive/Yolov8/data/valid/images/img-598_jpg.rf.ba92e243f003cf5d3b7951504dc21c8e.jpg: ignoring corrupt image/label: Label class 200 exceeds dataset class count 32. Possible class labels are 0-31
# val: WARNING ⚠️ /content/drive/MyDrive/Yolov8/data/valid/images/img-601_jpg.rf.b388f8e7847e536a8d0b4bebf76f2f58.jpg: ignoring corrupt image/label: Label class 200 exceeds dataset class count 32. Possible class labels are 0-31
# val: WARNING ⚠️ /content/drive/MyDrive/Yolov8/data/valid/images/img-603_jpg.rf.e1f5bc76f3b1f37d4436652525cd776f.jpg: ignoring corrupt image/label: Label class 200 exceeds dataset class count 32. Possible class labels are 0-31
# val: WARNING ⚠️ /content/drive/MyDrive/Yolov8/data/valid/images/img-604_jpg.rf.becbd4b220417ce4d19186e23c348c41.jpg: ignoring corrupt image/label: Label class 200 exceeds dataset class count 32. Possible class labels are 0-31
# val: WARNING ⚠️ /content/drive/MyDrive/Yolov8/data/valid/images/img-60_jpg.rf.ab6e2152eae420b9d6ed72067c2d2de4.jpg: ignoring corrupt image/label: Label class 200 exceeds dataset class count 32. Possible class labels are 0-31
# val: WARNING ⚠️ /content/drive/MyDrive/Yolov8/data/valid/images/img-611_jpg.rf.b81a7dd560243d748bf81779d88578db.jpg: ignoring corrupt image/label: Label class 200 exceeds dataset class count 32. Possible class labels are 0-31
# val: WARNING ⚠️ /content/drive/MyDrive/Yolov8/data/valid/images/img-615_jpg.rf.c957d1dcba988649c6eabf98bae75a26.jpg: ignoring corrupt image/label: Label class 200 exceeds dataset class count 32. Possible class labels are 0-31
# val: WARNING ⚠️ /content/drive/MyDrive/Yolov8/data/valid/images/img-629_jpg.rf.fa98ba6e30797471aef7a9b74612cae4.jpg: ignoring corrupt image/label: Label class 200 exceeds dataset class count 32. Possible class labels are 0-31
# val: WARNING ⚠️ /content/drive/MyDrive/Yolov8/data/valid/images/img-635_jpg.rf.d927a354594cf6149884c5be3e1823b4.jpg: ignoring corrupt image/label: Label class 200 exceeds dataset class count 32. Possible class labels are 0-31
# val: WARNING ⚠️ /content/drive/MyDrive/Yolov8/data/valid/images/img-643_jpg.rf.1a2296e4ddd593550e1d0d142a1a5ea1.jpg: ignoring corrupt image/label: Label class 200 exceeds dataset class count 32. Possible class labels are 0-31
# val: WARNING ⚠️ /content/drive/MyDrive/Yolov8/data/valid/images/img-648_jpg.rf.d2a3c4bc4ed7c6677d3c2e333f800fdc.jpg: ignoring corrupt image/label: Label class 200 exceeds dataset class count 32. Possible class labels are 0-31
# val: WARNING ⚠️ /content/drive/MyDrive/Yolov8/data/valid/images/img-650_jpg.rf.e88805e59a7f1cc913add78a3fbc5021.jpg: ignoring corrupt image/label: Label class 200 exceeds dataset class count 32. Possible class labels are 0-31
# val: WARNING ⚠️ /content/drive/MyDrive/Yolov8/data/valid/images/img-651_jpg.rf.9d23181946069eea42305c4169bc983a.jpg: ignoring corrupt image/label: Label class 200 exceeds dataset class count 32. Possible class labels are 0-31
# val: WARNING ⚠️ /content/drive/MyDrive/Yolov8/data/valid/images/img-656_jpg.rf.493ebfd54572f357930a938084268c89.jpg: ignoring corrupt image/label: Label class 200 exceeds dataset class count 32. Possible class labels are 0-31
# val: WARNING ⚠️ /content/drive/MyDrive/Yolov8/data/valid/images/img-658_jpg.rf.285e10fe9cbc54d706df8bcc035af5b5.jpg: ignoring corrupt image/label: Label class 200 exceeds dataset class count 32. Possible class labels are 0-31
# val: WARNING ⚠️ /content/drive/MyDrive/Yolov8/data/valid/images/img-67_jpg.rf.d56a42fb8a3d344cca532389685a17d3.jpg: ignoring corrupt image/label: Label class 200 exceeds dataset class count 32. Possible class labels are 0-31
# val: WARNING ⚠️ /content/drive/MyDrive/Yolov8/data/valid/images/img-69_jpg.rf.5f71daebea71c55717d8ce7f923ba9b6.jpg: ignoring corrupt image/label: Label class 200 exceeds dataset class count 32. Possible class labels are 0-31
# val: WARNING ⚠️ /content/drive/MyDrive/Yolov8/data/valid/images/img-77_jpg.rf.34415fbad0c24da0e8f26f852895571b.jpg: ignoring corrupt image/label: Label class 200 exceeds dataset class count 32. Possible class labels are 0-31
# val: WARNING ⚠️ /content/drive/MyDrive/Yolov8/data/valid/images/img-7_jpg.rf.9eb7df0def00c9b67f311458e677ea64.jpg: ignoring corrupt image/label: Label class 200 exceeds dataset class count 32. Possible class labels are 0-31
# val: WARNING ⚠️ /content/drive/MyDrive/Yolov8/data/valid/images/img-89_jpg.rf.4cc9eb15fe4de48faa685770d8299408.jpg: ignoring corrupt image/label: Label class 200 exceeds dataset class count 32. Possible class labels are 0-31
# val: WARNING ⚠️ /content/drive/MyDrive/Yolov8/data/valid/images/img-8_jpg.rf.1476b59188eb2734b6729af69f5cb4dc.jpg: ignoring corrupt image/label: Label class 200 exceeds dataset class count 32. Possible class labels are 0-31
# val: WARNING ⚠️ /content/drive/MyDrive/Yolov8/data/valid/images/img-91_jpg.rf.1eba3ec5933f74ea41d434550d5cb3ca.jpg: ignoring corrupt image/label: Label class 200 exceeds dataset class count 32. Possible class labels are 0-31
# val: WARNING ⚠️ /content/drive/MyDrive/Yolov8/data/valid/images/img-92_jpg.rf.84aa5ec68c57d302a51b8b0938e4e1c7.jpg: ignoring corrupt image/label: Label class 200 exceeds dataset class count 32. Possible class labels are 0-31
# val: WARNING ⚠️ /content/drive/MyDrive/Yolov8/data/valid/images/img-93_jpg.rf.7dc83bef4593a070f4cea15ebec8a527.jpg: ignoring corrupt image/label: Label class 200 exceeds dataset class count 32. Possible class labels are 0-31
# val: WARNING ⚠️ /content/drive/MyDrive/Yolov8/data/valid/images/img-94_jpg.rf.26ce6c0878886e2b49b0191cf4f952bb.jpg: ignoring corrupt image/label: Label class 200 exceeds dataset class count 32. Possible class labels are 0-31
# val: WARNING ⚠️ /content/drive/MyDrive/Yolov8/data/valid/images/pedestrian-crossing_jpg.rf.a13485fa164d3a21923c1b81960597b6.jpg: ignoring corrupt image/label: Label class 100 exceeds dataset class count 32. Possible class labels are 0-31
# val: WARNING ⚠️ /content/drive/MyDrive/Yolov8/data/valid/images/pedestrian3_jpg.rf.b14254bcdd4aeabfbd3f1ba0c089ae75.jpg: ignoring corrupt image/label: Label class 100 exceeds dataset class count 32. Possible class labels are 0-31
# val: WARNING ⚠️ /content/drive/MyDrive/Yolov8/data/valid/images/pedestrian5_jpg.rf.853d32723345106ff2d5c88f3ec3b208.jpg: ignoring corrupt image/label: Label class 100 exceeds dataset class count 32. Possible class labels are 0-31
# val: WARNING ⚠️ /content/drive/MyDrive/Yolov8/data/valid/images/pedestrian6_jpg.rf.0a62c71e77338f23e7f40bcca4090934.jpg: ignoring corrupt image/label: Label class 100 exceeds dataset class count 32. Possible class labels are 0-31
# val: WARNING ⚠️ /content/drive/MyDrive/Yolov8/data/valid/images/pedestrian_jpeg.rf.191e4030bbe385e479567ed2c5c83197.jpg: ignoring corrupt image/label: Label class 100 exceeds dataset class count 32. Possible class labels are 0-31
# val: WARNING ⚠️ /content/drive/MyDrive/Yolov8/data/valid/images/pr037-22_jpg.rf.1e35ca9ea3ce483865903523d234c1b8.jpg: ignoring corrupt image/label: Label class 100 exceeds dataset class count 32. Possible class labels are 0-31
# val: WARNING ⚠️ /content/drive/MyDrive/Yolov8/data/valid/images/shutterstock-elderly-pedestrian_jpg.rf.4c952e86020b14877d4cfdab9446c039.jpg: ignoring corrupt image/label: Label class 100 exceeds dataset class count 32. Possible class labels are 0-31
# val: WARNING ⚠️ /content/drive/MyDrive/Yolov8/data/valid/images/young-man-cross-street-1-scaled-e1644362792645_jpg.rf.f79d3de5f5138b1ef64fc07d85370f43.jpg: ignoring corrupt image/label: Label class 100 exceeds dataset class count 32. Possible class labels are 0-31
# Plotting labels to runs/detect/train2/labels.jpg...
# optimizer: 'optimizer=auto' found, ignoring 'lr0=0.01' and 'momentum=0.937' and determining best 'optimizer', 'lr0' and 'momentum' automatically...
# optimizer: AdamW(lr=0.000278, momentum=0.9) with parameter groups 57 weight(decay=0.0), 64 weight(decay=0.0005), 63 bias(decay=0.0)
# TensorBoard: model graph visualization added ✅
# Image sizes 640 train, 640 val
# Using 0 dataloader workers
# Logging results to runs/detect/train2
# Starting training for 10 epochs...
# Closing dataloader mosaic
# albumentations: Blur(p=0.01, blur_limit=(3, 7)), MedianBlur(p=0.01, blur_limit=(3, 7)), ToGray(p=0.01), CLAHE(p=0.01, clip_limit=(1, 4.0), tile_grid_size=(8, 8))
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        1/10         0G      1.874      5.664      2.648         16        640:   4%|▍         | 17/444 [05:34<2:19:53, 19.66s/it]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-10-a6eb00777fb4> in <cell line: 7>()
#       5
#       6 # Use the model
# ----> 7 model.train(data="data.yaml", epochs=10)
#       8 metrics = model.val()
#
# /usr/local/lib/python3.10/dist-packages/ultralytics/engine/model.py in train(self, trainer, **kwargs)
#     599
#     600         self.trainer.hub_session = self.session  # attach optional HUB session
# --> 601         self.trainer.train()
#     602         # Update model and cfg after training
#     603         if RANK in (-1, 0):
#
# /usr/local/lib/python3.10/dist-packages/ultralytics/engine/trainer.py in train(self)
#     206
#     207         else:
# --> 208             self._do_train(world_size)
#     209
#     210     def _setup_scheduler(self):
#
# /usr/local/lib/python3.10/dist-packages/ultralytics/engine/trainer.py in _do_train(self, world_size)
#     382
#     383                 # Backward
# --> 384                 self.scaler.scale(self.loss).backward()
#     385
#     386                 # Optimize - https://pytorch.org/docs/master/notes/amp_examples.html
#
# /usr/local/lib/python3.10/dist-packages/torch/_tensor.py in backward(self, gradient, retain_graph, create_graph, inputs)
#     490                 inputs=inputs,
#     491             )
# --> 492         torch.autograd.backward(
#     493             self, gradient, retain_graph, create_graph, inputs=inputs
#     494         )
#
# /usr/local/lib/python3.10/dist-packages/torch/autograd/__init__.py in backward(tensors, grad_tensors, retain_graph, create_graph, grad_variables, inputs)
#     249     # some Python versions print out the first line of a multi-line function
#     250     # calls in the traceback and some print out the last line
# --> 251     Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
#     252         tensors,
#     253         grad_tensors_,
#
# KeyboardInterrupt:

# %%
# !ls runs/detect/train
# Out:
# args.yaml					   labels.jpg	     train_batch1.jpg
# events.out.tfevents.1707467233.2d3186f32af3.823.1  results.csv	     train_batch2.jpg
# labels_correlogram.jpg				   train_batch0.jpg  weights
